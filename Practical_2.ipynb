# %% [markdown]
# <a href="https://colab.research.google.com/github/kprashik93/Machine-Learning-/blob/main/Practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
 
df = pd.read_csv('/train.csv')

# %%
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.loc[0:10,'Age':'Embarked']
# Out:
#      Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0   22.0      1      0         A/5 21171   7.2500   NaN        S
# 1   38.0      1      0          PC 17599  71.2833   C85        C
# 2   26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3   35.0      1      0            113803  53.1000  C123        S
# 4   35.0      0      0            373450   8.0500   NaN        S
# 5    NaN      0      0            330877   8.4583   NaN        Q
# 6   54.0      0      0             17463  51.8625   E46        S
# 7    2.0      3      1            349909  21.0750   NaN        S
# 8   27.0      0      2            347742  11.1333   NaN        S
# 9   14.0      1      0            237736  30.0708   NaN        C
# 10   4.0      1      1           PP 9549  16.7000    G6        S

# %%
df.loc[0:6,'Fare']
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# 6    51.8625
# Name: Fare, dtype: float64

# %%
df.loc[0:3,'Name']
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Name: Name, dtype: object

# %%
df.iloc[0:4,0:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1

# %%
df['Age']==df['Age'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age']==df['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df.sort_values(by='PassengerId',ascending=True).head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
 new = {0:'male',1:'female'}
df['sex']=df['Sex'].map(new)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  sex
# 0            1         0       3  ...   NaN        S  NaN
# 1            2         1       1  ...   C85        C  NaN
# 2            3         1       3  ...   NaN        S  NaN
# 3            4         1       1  ...  C123        S  NaN
# 4            5         0       3  ...   NaN        S  NaN
#
# [5 rows x 13 columns]

# %%
old = {0:'male', 1:'female'}
df= df.replace({'sex':old}) 
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  sex
# 0            1         0       3  ...   NaN        S  NaN
# 1            2         1       1  ...   C85        C  NaN
# 2            3         1       3  ...   NaN        S  NaN
# 3            4         1       1  ...  C123        S  NaN
# 4            5         0       3  ...   NaN        S  NaN
#
# [5 rows x 13 columns]

# %%
df.groupby(by='Survived') ['Age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0         424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1         290.0  28.343690  14.950952  0.42  19.0  28.0  36.0  80.0

# %%
pd.crosstab(df['Sex'], df['Survived'], normalize = True)
# Out:
# Survived         0         1
# Sex
# female    0.090909  0.261504
# male      0.525253  0.122334
